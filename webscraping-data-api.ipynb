# %%
import httplib
#import TwitterSearch
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-3931a62cb96a> in <module>()
# ----> 1 auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#       2 auth.set_access_token(access_token, access_token_secret)
#
# NameError: name 'consumer_key' is not defined

# %%
conn = httplib.HTTPConnection('api.twitter.com/oauth2/token')
conn.request("HEAD","/")
res = conn.getresponse()


import requests
from requests_oauthlib import OAuth1

url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1('YOUR_APP_KEY', 'YOUR_APP_SECRET',
                  'USER_OAUTH_TOKEN', 'USER_OAUTH_TOKEN_SECRET')

requests.get(url, auth=auth)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-67-878c41156341> in <module>()
#       1 conn = httplib.HTTPConnection('api.twitter.com/oauth2/token')
# ----> 2 conn.request("HEAD","/")
#       3 res = conn.getresponse()
#       4
#       5
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1055     def request(self, method, url, body=None, headers={}):
#    1056         """Send a complete request to the server."""
# -> 1057         self._send_request(method, url, body, headers)
#    1058
#    1059     def _set_content_length(self, body, method):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1095         for hdr, value in headers.iteritems():
#    1096             self.putheader(hdr, value)
# ...

# %%
print res.status, res.reason
# Out:
# 302 Found

# %%
from TwitterSearch import *
try:
    tso = TwitterSearchOrder() # create a TwitterSearchOrder object
    tso.set_keywords(['ixl', 'education']) # let's define all words we would like to have a look for
    tso.set_language('en') # we want to see German tweets only
    tso.set_include_entities(False) # and don't give us all those entity information

    # it's about time to create a TwitterSearch object with our secret tokens
    ts = TwitterSearch(
        consumer_key = "gPLmSssLEYfqkrpLjhBWBxFgb",
        consumer_secret = "Cj4BorKfeEW6eZGTWOVkoLbXmYex3X7RHXn4rzdabzpqpcNErv",
        access_token = "721080318300655617-2nC0EztP9Q5xHExCMTqDDzQ4DEjnZdM",
        access_token_secret = "ajX6Rn1gzFY95vEokqZP25TOo7UDx7jGXHwQFg3LK0evM",
     )

     # this is where the fun actually starts :)
    for tweet in ts.search_tweets_iterable(tso):
        print( '@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text'] ) )

except TwitterSearchException as e: # take care of all those ugly errors if there are some
    print(e)
# Out:
# @IXLRecruiting tweeted: IXL was featured as one of four exciting summer learning acitivities for students! https://t.co/aBMBrIGp2a
# @IanMooreSr tweeted: RT @edtechking: "Programs like #IXL are huge for the students, for just learning and becoming better on these computers."  #edtech
#
# https:/…
# @IXLLearning tweeted: RT @edtechking: "Programs like #IXL are huge for the students, for just learning and becoming better on these computers."  #edtech
#
# https:/…
# @edtechking tweeted: "Programs like #IXL are huge for the students, for just learning and becoming better on these computers."  #edtech
#
# https://t.co/yOISJafLjx

# %%
consumer_token = "gPLmSssLEYfqkrpLjhBWBxFgb"
consumer_secret = "Cj4BorKfeEW6eZGTWOVkoLbXmYex3X7RHXn4rzdabzpqpcNErv"

auth = tweepy.OAuthHandler(consumer_token, consumer_secret)


try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print 'Error! Failed to get request token.'
print redirect_url
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=rD9aNgAAAAAAvs8ZAAABVWZ7IK0

# %%
import oauth2 as oauth
import json

CONSUMER_KEY = "gPLmSssLEYfqkrpLjhBWBxFgb"
CONSUMER_SECRET = "Cj4BorKfeEW6eZGTWOVkoLbXmYex3X7RHXn4rzdabzpqpcNErv"
ACCESS_KEY = "721080318300655617-2nC0EztP9Q5xHExCMTqDDzQ4DEjnZdM"
ACCESS_SECRET = "ajX6Rn1gzFY95vEokqZP25TOo7UDx7jGXHwQFg3LK0evM"

consumer = oauth.Consumer(key=CONSUMER_KEY, secret=CONSUMER_SECRET)
access_token = oauth.Token(key=ACCESS_KEY, secret=ACCESS_SECRET)
client = oauth.Client(consumer, access_token)

timeline_endpoint = "https://api.twitter.com/1.1/statuses/home_timeline.json"
response, data = client.request(timeline_endpoint)

tweets = json.loads(data)
for tweet in tweets:
    print (tweet['text'])
# Out:
# #LeCorsaire
# The epic ballet with @ENBallet. Soon!" https://t.co/X24yxVYrY9
# RT @AgileFi: #BigData IBM Watson's Big Moves, Machine Learning Everywhere, Big Data Roundup: Microsoft will soon ... https://t.co/OgjVHfXhj…
# RT @CydneeBrook: I got to meet @brookewellss and it was great thank you for being lovely! #goodlukeforthegames #hero #whateverittakes https…
# RT @speak2marcus: Had a great time at the frenchthrowdown in Paris with @brookewellss and our friends… https://t.co/pxpDyfBruz
# -i can't think of a reason why it would be different (for growth)? https://t.co/l18kmJJcPQ
# Guys Turn To Whisper To Vent Their Feelings About Orlando https://t.co/3JDtb3Exe4 #orlando #tragedy #whisperapp https://t.co/KjuvYrz7Po
# Predominantly LGBT Megachurch @CathedralOfHope in Dallas Evacuated Due to Bomb Threat https://t.co/F2BxJkivHZ https://t.co/S8upZPqQyZ
# RT @techjunkiejh: #BigData and Apache #Hadoop for Financial Services https://t.co/HfjdCuIJCv #fintech https://t.co/IjcpQFnp5Q
# ...

# %%
from bs4 import BeautifulSoup
import html5lib

import urllib
r = urllib.urlopen('https://www.edsurge.com/product-reviews/ixl-learning').read()
soup = BeautifulSoup(r)
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print soup.prettify()[0:1000]
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# edsurge: http://ogp.me/ns/fb/edsurge#">
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"caca9da897","applicationID":"527331","transactionName":"c1oLQRQMD1wGRhxHQl9REFYSEExDC1tE","queueTime":43,"applicationTime":49,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
print soup.prettify()[0:1000]
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# edsurge: http://ogp.me/ns/fb/edsurge#">
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"caca9da897","applicationID":"527331","transactionName":"c1oLQRQMD1wGRhxHQl9REFYSEExDC1tE","queueTime":43,"applicationTime":49,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
r = urllib.urlopen('https://www.graphite.org/website/ixl').read()
soup = BeautifulSoup(r)
print type(soup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="no-js iem7"  lang="en" dir="ltr" ng-app="graphite"><![endif]-->
# <!--[if lte IE 6]><html class="no-js lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr" ng-app="graphite"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="no-js lt-ie9 lt-ie8"  lang="en" dir="ltr" ng-app="graphite"><![endif]-->
# <!--[if IE 8]><html class="no-js lt-ie9"  lang="en" dir="ltr" ng-app="graphite"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html class="no-js" dir="ltr" lang="en" ng-app="graphite" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
#  <!--<![endif]-->
#  <head>
#   <!--[if IE]><![endif]-->
#   <meta charset="utf-8"/>
# ...

# %%
spans = soup.find_all('span', attrs="label")
for span in spans:
    print span.string
# Out:
# Graphite Rating
# Teacher Rating
# Setup Time
# Additional Pricing Details
# Evidence
# Teacher Dashboard
# Tech Notes
# Graphite Rating
# Engagement
# Pedagogy
# Support
# How Can Teachers Use It?
# What's It Like?
# Is It Good For Learning?
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating
# Graphite Rating
# Teacher Rating

# %%
auth = tweepy.OAuthHandler("consumer_key", "consumer_secret")

# Redirect user to Twitter to authorize
tweepy.redirect_user(auth.get_authorization_url())

# Get access token
auth.get_access_token("verifier_value")

# Construct the API instance
api = tweepy.API(auth)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-cc85b5e28069> in <module>()
#       2
#       3 # Redirect user to Twitter to authorize
# ----> 4 tweepy.redirect_user(auth.get_authorization_url())
#       5
#       6 # Get access token
#
# AttributeError: 'module' object has no attribute 'redirect_user'
